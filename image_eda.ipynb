# %%
import pydicom as dicom
import pandas as pd
import cv2
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# for the surface map
from mpl_toolkits.mplot3d import Axes3D
ds=dicom.read_file('000db696-cf54-4385-b10b-6b16fbb3f985.dcm')
df = pd.DataFrame(ds.values())
df[0] = df[0].apply(lambda x: dicom.dataelem.DataElement_from_raw(x) if isinstance(x, dicom.dataelem.RawDataElement) else x)
df['name'] = df[0].apply(lambda x: x.name)
df['value'] = df[0].apply(lambda x: x.value)
df = df[['name', 'value']]

# %%
df.head()
# Out:
#                      name                                              value
# 0  Specific Character Set                                         ISO_IR 100
# 1           SOP Class UID                          1.2.840.10008.5.1.4.1.1.7
# 2        SOP Instance UID  1.2.276.0.7230010.3.1.4.8323329.4475.151787430...
# 3              Study Date                                           19010101
# 4              Study Time                                          000000.00

# %%
dicom.__version__
# Out:
# '2.2.2'

# %%
plt.figure(figsize=(10,10))
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
plt.show()

# %%
import pydicom as dicom
import pandas as pd

ds1=dicom.read_file('1.2.276.0.7230010.3.1.4.8323329.1472.1517874291.114975.dcm')
df1 = pd.DataFrame(ds1.values())
df1[0] = df1[0].apply(lambda x: dicom.dataelem.DataElement_from_raw(x) if isinstance(x, dicom.dataelem.RawDataElement) else x)
df1['name'] = df1[0].apply(lambda x: x.name)
df1['value'] = df1[0].apply(lambda x: x.value)
df1 = df1[['name', 'value']]

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# for the surface map
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(10,10))

ax = plt.axes(projection='3d')

y = range( ds.pixel_array.shape[0] )
x = range( ds.pixel_array.shape[1] ) 
X, Y = np.meshgrid(x, y)

ax.plot_surface( X, Y, ds.pixel_array[:,:] ,cmap=plt.cm.gray)

plt.show()

# %%
plt.figure(figsize=(10,10))

ax = plt.axes(projection='3d')

y = range(0,500)
x = range(0,500)
X, Y = np.meshgrid(x, y)

ax.plot_surface( X, Y, ds.pixel_array[:500,:500] ,cmap=plt.cm.gray)

plt.show()

# %%
plt.figure(figsize=(10,10))

ax = plt.axes(projection='3d')

y = range(0,500)
x = range(0,500)
X, Y = np.meshgrid(x, y)

ax.plot_surface( X, Y, ds.pixel_array[200:700,200:700] ,cmap=plt.cm.gray)

plt.show()

# %% [markdown]
# ##Analysis for a non pneumonia patient

# %%
#fffc95b5-605b-4226-80ab-62caec682b22
ds_nn=dicom.read_file('0004cfab-14fd-4e49-80ba-63a80b6bddd6.dcm')

plt.figure(figsize=(10,10))
plt.imshow(ds_nn.pixel_array, cmap=plt.cm.gray)
plt.show()

# %%
plt.figure(figsize=(10,10))

ax = plt.axes(projection='3d')

y = range( ds_nn.pixel_array.shape[0] )
x = range( ds_nn.pixel_array.shape[1] ) 
X, Y = np.meshgrid(x, y)

ax.plot_surface( X, Y, ds_nn.pixel_array[:,:] ,cmap=plt.cm.gray)

plt.show()

# %%
plt.figure(figsize=(10,10))

ax = plt.axes(projection='3d')

y = range(0,500)
x = range(0,500)
X, Y = np.meshgrid(x, y)

ax.plot_surface( X, Y, ds_nn.pixel_array[200:700,200:700] ,cmap=plt.cm.gray)

plt.show()
